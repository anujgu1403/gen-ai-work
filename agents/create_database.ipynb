# %%
from pathlib import Path
from sqlalchemy import create_engine

DB_PATH = Path("/Users/anujmittal/Desktop/ai_agentic/data/agent_sessions.db")
DATABASE_URL = f"sqlite:///{DB_PATH}"

engine = create_engine(DATABASE_URL)
engine.connect()

print("✅ agent_sessions.db created at:", DB_PATH)
# Out:
# ✅ agent_sessions.db created at: /Users/anujmittal/Desktop/ai_agentic/data/agent_sessions.db
